# %% [markdown]
# چطور یک مدل زبانی مثل برت را روی دیتاست جدید فاین تیون کنم؟ فرض کن میخوای یه مدل پریترین مثل پارس برت رو ببری تو حوزه حقوقی یا سیاسی. پس بهتره روی یک کورپس حقوقی یا سیاسی مجدد فاین تیون کنی همون پارس برت رو. اینجوری کلمات توی حوزه مورد نظرتو بهتر میتونه پیش بینی کنه.

# %%
اولش بیا و دو پکیج ترنسفرمرها و دیتاست ها رو نصب کن. ترنسفر ها ک همون مدلهای مبتنی بر ترنسفرمرها رو داره، دیتاست هم شامل دیتاست های اماده ای هست که راحت میتونی ازشون استفاده کنی

# %%
! pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 57.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 13.2 MB/s eta 0:00:00
# ...

# %%
خب مگه میخوای از مدلها و دیتاهاس هاگین فیس استفاده کنی؟ پس توکن شناسایی خودتو از حساب کاربری هاگین فیست بردار و خودتو تایید هویت کن.

# %% [markdown]
#  (sign up [here](https://huggingface.co/join)if you haven't already!)

# %%
from huggingface_hub import notebook_login
notebook_login()#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

# %% [markdown]
# Git-LFS هم نصب کن. فعلا نمیدونم دقیقا چیه بعدا میگم بهت

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.9.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %% [markdown]
# خب چک کن که حداقل ورژن ترنسفرمرت 4.11 باشه

# %% [markdown]
# import transformers
#
# print(transformers.__version__)

# %% [markdown]
# خب اولش بیا دیتاست رو اماده کنیم

# %% [markdown]
# من داده های فارسی میخوام برای همین توی هاگین فیس سرچ کردم پرشین و یه داده فارسی برای مدل زبانی پیدا کردم. این تیپ داده باید متن ساده باشه. معمولا مینوسن مخصوص اموزش مدل زبانی. تو اگه انگلیسی میخوای خب بزن انگلیش. الان توی همین مثال پایین هم اون خط کامنت شده ی دیتاست انگلیسیه این کد خودش ترین و تست هم جدا میکنه قشنگ.

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-2886e92a-4861-4b2f-a5cc-b8de572dda91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2886e92a-4861-4b2f-a5cc-b8de572dda91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d miladfa7/persian-wikipedia-dataset
# Out:
# ...
#  96% 201M/209M [00:02<00:00, 79.1MB/s]
# 100% 209M/209M [00:02<00:00, 83.2MB/s]

# %%
# !unzip persian-wikipedia-dataset.zip
# Out:
# Archive:  persian-wikipedia-dataset.zip
#   inflating: Persian-WikiText-1.txt
#   inflating: Persian-WikiText-2.txt
#   inflating: Persian-WikiText-3.txt
#   inflating: Persian-WikiText-4.txt
#   inflating: Persian-WikiText-5.txt
#   inflating: Persian-WikiText-6.txt
#   inflating: Persian-WikiText-7.txt
#   inflating: Persian-WikiText-8.txt
#   inflating: Persian-WikiText-9.txt

# %%
from datasets import load_dataset
#datasets = load_dataset('wikitext', 'wikitext-2-raw-v1')
datasets=load_dataset("RohanAiLab/persian_blog")

# %%
from datasets import load_dataset
#datasets = load_dataset("text", data_files="/content/data.txt")
datasets = load_dataset("text", data_files={"train": "/content/train.txt", "validation": "/content/data.txt"})
# Out:
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-5c9983588427b406/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 477
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 157
#     })
# })

# %% [markdown]
# خب دیگه بریم سر اصل مطلب. اول بریم ی مدل زبانی پری ترین شده رو برداریم. توی همون هاگین فیس سرچ کنی مدل زبانی کلی میاره برای هر زبانی. من فعلا پارس برت برای مدل زبانی رو میخوام. ببین هواست باشه نری پارس برت برای تسک خاص مثل ترجمه اینا برداریا. اونا فاین تیون شده روی اون تسکند. تو ی مدل زبانی خام ولی پری ترین روی کورپس رو فقط میخوای.

# %%
model_checkpoint = "HooshvareLab/bert-fa-base-uncased"

# %%
from transformers import AutoTokenizer

# %% [markdown]
# یه توکنایزر روی کل متن میخوام. پس ی تابع براش مینویسم ک از همون توکنایزری ک موقع ترین استفاده شده الانم استفاده کنیم. هدف ما اینه متن ها رو توکن توکن کنیم بر اساس همون وکبی ک مدل اصلی ترین شده قبلا. عملا ب هر کلمه یک ای دی بر اساس اون وکب نسبت میدیم.

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)

# %%
tokenizer.save_pretrained("/content/bert-fa-base-uncased-finetuned-ParsBert")
# Out:
# ('/content/bert-fa-base-uncased-finetuned-ParsBert/tokenizer_config.json',
#  '/content/bert-fa-base-uncased-finetuned-ParsBert/special_tokens_map.json',
#  '/content/bert-fa-base-uncased-finetuned-ParsBert/vocab.txt',
#  '/content/bert-fa-base-uncased-finetuned-ParsBert/added_tokens.json',
#  '/content/bert-fa-base-uncased-finetuned-ParsBert/tokenizer.json')

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"])

# %%
tokenized_datasets = datasets.map(tokenize_function, batched=True, num_proc=4, remove_columns=["text"])
# Out:
# ...
# Map (num_proc=4):   0%|          | 0/157 [00:00<?, ? examples/s]

# %%
# block_size = tokenizer.model_max_length
block_size = 128

# %%
def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
        # customize this part to your needs.
    total_length = (total_length // block_size) * block_size
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

# %%
lm_datasets = tokenized_datasets.map(
    group_texts,
    batched=True,
    batch_size=16,
    num_proc=4,
)
# Out:
# ...
# Map (num_proc=4):   0%|          | 0/157 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForMaskedLM
model = AutoModelForMaskedLM.from_pretrained(model_checkpoint)
# Out:
# Some weights of the model checkpoint at HooshvareLab/bert-fa-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from transformers import Trainer, TrainingArguments

# %%
model_name = model_checkpoint.split("/")[-1]
training_args = TrainingArguments(
    f"{model_name}-finetuned-ParsBert",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    push_to_hub=True,
)

# %%
from transformers import DataCollatorForLanguageModeling
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)

# %%
"""trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_datasets["train"],
    eval_dataset=lm_datasets["validation"],
    data_collator=data_collator,
)"""
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_datasets["train"],
    eval_dataset=lm_datasets["validation"],
    data_collator=data_collator,
)
# Out:
# /content/bert-fa-base-uncased-finetuned-ParsBert is already a clone of https://huggingface.co/Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/bert-fa-base-uncased-finetuned-ParsBert is already a clone of https://huggingface.co/Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='24' max='24' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [24/24 09:28, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
# ...

# %%
import math

# %%
eval_results = trainer.evaluate()
print(f"Perplexity: {math.exp(eval_results['eval_loss']):.2f}")
# Out:
#     <div>
#
#       <progress value='8' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4/4 01:20]
#     </div>
# Perplexity: 6.20

# %%
trainer.push_to_hub()
# Out:
# To https://huggingface.co/Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert
#    39ef935..3e17dac  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert
#    39ef935..3e17dac  main -> main
# 'https://huggingface.co/Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert/commit/3e17dac53ff0ba4ee653ccfba7d34e5314aef81c'

# %%
from transformers import AutoModelForMaskedLM
model = AutoModelForMaskedLM.from_pretrained("Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert")

# %%
tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert")

model = AutoModelForMaskedLM.from_pretrained("Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert")

# %%
from transformers import pipeline

# %%
clf = pipeline("fill-mask", model="Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert", tokenizer="Yasamansaffari73/bert-fa-base-uncased-finetuned-ParsBert")

# %%
clf(" درضمن به ارائه مشاوره در خصوص مراحل [MASK] تکنولوژی می پردازد")
# Out:
# [{'score': 0.012633905746042728,
#   'token': 6571,
#   'token_str': 'مشاوره',
#   'sequence': 'درضمن به ارايه مشاوره در خصوص مراحل مشاوره تکنولوژی می پردازد'},
#  {'score': 0.012260999530553818,
#   'token': 5706,
#   'token_str': 'نوین',
#   'sequence': 'درضمن به ارايه مشاوره در خصوص مراحل نوین تکنولوژی می پردازد'},
#  {'score': 0.009777055121958256,
#   'token': 3821,
#   'token_str': '##داف',
#   'sequence': 'درضمن به ارايه مشاوره در خصوص مراحلداف تکنولوژی می پردازد'},
#  {'score': 0.006501653231680393,
#   'token': 3503,
#   'token_str': 'ساله',
#   'sequence': 'درضمن به ارايه مشاوره در خصوص مراحل ساله تکنولوژی می پردازد'},
#  {'score': 0.005363153293728828,
#   'token': 6112,
#   'token_str': 'انع',
#   'sequence': 'درضمن به ارايه مشاوره در خصوص مراحل انع تکنولوژی می پردازد'}]
